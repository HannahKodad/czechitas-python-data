# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"
data = pd.read_csv(url)

# %%
data.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
data["species"].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
data[data["island"] == "Dream"]["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap'], dtype=object)

# %%
len(data[data["body_mass_g"] > 5000])
# Out:
# 61

# %%
len(data[(data["body_mass_g"] < 3500) & (data["flipper_length_mm"] > 200)])
# Out:
# 1

# %%
len(data[(data["island"] == "Torgersen") & (data["sex"] == "female")])
# Out:
# 24

# %%
data["year"].value_counts()
# Out:
# year
# 2009    120
# 2008    114
# 2007    110
# Name: count, dtype: int64

# %%
data["body_mass_g"].median()
# Out:
# np.float64(4050.0)
