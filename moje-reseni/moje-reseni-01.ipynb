# %% [markdown]
# ## Titanic data set
#
# Každý tutoriál datové analýzy začíná zpracováváním data setu pasažérů lodi Titanic.
#
# Nebude tomu jinak ani v našem případě. Stáhni si soubor [titanic.csv](https://kodim.cz/cms/assets/czechitas/python-data-1/python-pro-data-1/nacteni-dat/excs/titanic/titanic.csv).

# %% [markdown]
# Načti data do `DataFrame`, který si pojmenuj `titanic`.

# %%
import pandas as pd

# %%
url = "https://kodim.cz/cms/assets/czechitas/python-data-1/python-pro-data-1/nacteni-dat/excs/titanic/titanic.csv"
titanic = pd.read_csv(url) # nebo jina cesta k souboru

# %% [markdown]
# Nech si zobrazit názvy sloupců, které jsou v souboru uloženy.

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Podívej se, kolik má soubor řádků.

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# Zjisti, v jakých sloupcích nějaké hodnoty chybí.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum() #analýza chybějících hodnot
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.isnull().mean() * 100  # procenta, Chybějící hodnoty podle sloupců
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic.columns[titanic.isnull().any()] #jen sloupce s chybějícími hodnotami
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic.isnull().sum().plot(kind='bar')     #Rychlé vizuální
# Out:
# <Axes: >
